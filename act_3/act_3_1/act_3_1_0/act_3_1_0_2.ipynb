# %% [markdown]
# #
#
# # 22
#
# #
#
# [Incorporating your work on Generative AI into clinical stuff](https://www.youtube.com/watch?v=OE7Sqy-fx7g):
#
# 1. Curtis Langlotz/Standford
#    - Knowledge engineers
#    - Partner with clinicians/experts
#    - Implement systems to diagnose and treat
#    - Those systems would take 4 years and a PhD to build
#    - We can do so in a manner of days or weeks, with more accuracy
#    - Look at images, describe them in text, captioning
#    - My lab is focused on image analysis
#    - Communication between patients and doctors (like APIs can be AI now)
#    - Between physician communications (patients have access but can't understand)
#    - LLMs can create a hyperlinked document that can be used by patients to explain
#    - And what does LLM mean for the large image repos we have?
#       - Language is a sequence of medical events
#       - Not just to predict the next word but event
#       - Can be used across different decision/support apps
#    - Using generative images (DALLE, Stable diffusion)
#       - Create synthetic images based on a report
#       - May be used to supplement training data for image classification
#
# 2. Chris (Callison-Butch)/Penn
#    - Radiology has the largest corpous of digital data of all specialities
#    - Natural language processing for 20y
#    - OpenAI completely swallowed my field
#    - Career existential crisis (damn it)
#    - I've gone through many iterations of this
#    - Have calmed down and don't think ChatGPT will replace us
#    - But what are the things that LLMs are best for? Limitations?
#    - Some cautionary tales are worth flagging
#    - Explainable models of AI (especially in healthcare)
#    - May want reasoning that is faithful to your field in diagnosis
#
# 3. Tinglong Dai/Carey Business School
#    - AI and medicine have been dancing together for a long time
#    - Neuroscience, radiology, network analysis, etc.
#    - Most young docs at Hopkins are using ChatGPT at Hopkins
#    - ChatGPT is too nice and agreeable
#       - Medical colleagues are not happy with this
#       - Even when they ask it to critique them
#       - Chris
#          - `Pre-training + Fine-tuning = ChatGPT (Winning combo)`
#          - A version of GPT which is differential is easy to fix
#          - Such as modelling a particular bedside manner
#    - Improving access to healthcare
#       - Curtis: important beyond generative AI
#       - The lung nodules missed by radiologists diff. from those missed by AI
#       - So taken together they are as complementary
#       - Also can make non Hopkins/Standford physicians better, best
#       - Lots of underserved areas in Africa benefitting from AI
#       - Radiologists aren't available 24/7 in each hospital in UG
#
# 4. Risa Wolfe/SoM
#    - Validation in a healthcare system
#    - Screening for diabetic retinopathy
#    - Access to care increasing
#    - Healthcare delivery
#       - What are we going to encounter?
#       - Chris
#          - Privacy for health records
#          - Clinical decisions
#          - Tools for anyone
#            - ChatGPT is most accessible ($20/month: allows upload spreadsheets)
#            - Claude: upload documents and have conversations
#     - Curtis
#        - Explanation in healthcare is key
#        - Trust is another in clinical trials
#        - Different kind of intelligence (sounds smart)
#        - But there are really gaps in the apps
#        - Need for validation (engineering solutions are internal validation)
#        - Where are its priors coming from for a differential diagnosis?
#        - Do you want your doctor trained on reddit?
#        - LLM are trained on the internet!
#        - More likely to be applied to patient communication
#        - Diagnostic decision support may come later
#        - Lets bring self-supervision of GPT to purely clinical data
#        - For now its trained on everything (the internet)
#        - FDA doing a good job of regulating AI products for radiology
#        - We have the advantage over other industries in having an agency that is
#          already regulating AI
#        - `LLM, fine-tuned to specific circumstances (e.g. patient population)`
#    - Residency training, medical education, and research in 5-10y
#        - Curtis: we felt like this when MRI first emerged
#           - Understanding the physics would help understand artifacts
#           - Such as phase encoding; so introduced it into residency
#           - Had to understand how it works in a general way to understand artifacts
#           - Will have to do this with ChatGPT (worry, worry with younger students)
#        - Chris: its not a plagiarists tool (we feared at Penn initially)
#           - Patient-driven education
#           - Supplanting things that would've been done on web searches
#           - GPT was trained on Reddit and more!! So better than search!!!
#           - A conversation will be more engaging than a web search
#    - Physicians who don't use ChatGPT
#       - For now they will be behind
#       - How are colleagues using it?
#       - New capabilities will be introduced
#       - Curtis: Multimodal data: genetic, images, text, etc. Big deal
#       - Chris: equity across languages: most developed in English
#    - Evaluating the clinical utility of AI (e.g. diagnostic)
#       - Should we use RCTs?
#       - If AI is measuring diameter of aorta (human can verify)
#          - Must we squander resources on RCTs?
#       - Perhaps some will need RCTs other not
#          - FURM assessment (rubric)
#             - Fairness, interpretability, reliability, and model
#             - Usability
#             - Reliability (roc)
#             - Monetary and sustainability (roi on AI)
#                - capacity to act on result (e.g. aorta)
#                - unknown peripheral artery diseasse
#                - do we have the capacity in our clinic to handle those patients
#                - how does it fit in our workflow?
