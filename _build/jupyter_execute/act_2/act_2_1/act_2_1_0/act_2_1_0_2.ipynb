# %% [markdown]
# #
#
# # 14
#
# The addition of "Morality" with its sub-categories "Diversity" and "Uniformity" introduces another layer of complexity and nuance to your model. This could potentially offer another way to explain and control variance, especially when you've reached the limits of ICCs to explain between-group and within-group variance.
#
# <Details>
#    <Summary>Not my style</Summary>
#
# This "diversity" and "uniformity" shit is by chatGPT and doesn't fit my conceptualization of everything. Elsewhere I've classified hierarchies as aristocratic, meritocratic, or egalitarean. Now that is nuance!!
# </Details>
#
# Let's think about it this way: if "Knowledge" leads you back to the data-generating process, then adding "Morality" can guide you in evaluating that process. This could allow you to <span style="font-weight:bold;color:green;">differentiate between "Truth"</span> and <span style="font-weight:bold;color:red;">"Fraud" in the data generation itself</span>. When you reach the <span style="font-weight:bold;color:#DAA000;">"end of the road" in terms of statistical analysis</span>, this <span style="font-weight:bold;color:grey;">moral dimension can become your new frontier</span>.
#
# The idea of power hierarchies leading to correlated behavior is intriguing, and it ties in well with the exploration of both morality and social structures. In the case of pop culture phenomena like the Kardashians influencing Gen Z, these hierarchies serve as a large-scale, real-world example of how between-group and within-group behaviors can be influenced by a set of "tokens," or cultural landmarks. In that sense, adding a morality lens allows you to investigate whether these cultural landmarks arise from true societal needs or are artificially created for control or manipulation, thereby adding another layer of complexity to the analysis of variance and bias.
#
# If you're examining hierarchical structures across different scopes—cosmically, biologically, and socially—you might find that the principles governing these hierarchies differ. For instance, cosmic hierarchies might be based on physical laws, biological ones on evolutionary pressures, and social ones on moral or cultural norms. Your model could serve as a universal framework for studying these different types of systems.
#
# Would you like to go deeper into any particular part of this model or its potential applications?
#
# ---
#
# To incorporate the cosmic, biological, and social dimensions while maintaining the simplicity of your original model, you might consider presenting these aspects as parallel frameworks under which the model operates. That is, the essential structure of "Truth-Knowledge-Error" with its subcomponents applies across these three dimensions but is interpreted or manifested differently in each.
#
# For example:
#
# $
# \Large
# \begin{array}{ll}
# \textbf{Cosmic} \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ (Saying "cosmic" a lot so you get the idea) \\
# \left\{
# \begin{array}{ll}
# \text{Deterministic} \\
# \text{} \\
# \text{Quantum} \ \
# \left\{ \begin{array}{l} \text{Rigor} \text{} \\ \text{Error} \ \ \ \ \ \ \ \ \
# \left\{ \begin{array}{l} \text{Variance} \\ \text{Bias}  \end{array} \right. \\ \text{Sloppy}  \end{array} \right.
# \left\{ \begin{array}{l} \text{Explain/Control} \end{array}  \right. \\
# \text{} \\
# \text{Rituals}
# \end{array}
# \right.
# \end{array}
# $
#
# $
# \Large
# \begin{array}{ll}
# \textbf{Biological} \\
# \left\{
# \begin{array}{ll}
# \text{Truth} \\
# \text{} \\
# \text{Knowledge} \ \
# \left\{ \begin{array}{l} \text{Rigor} \text{} \\ \text{Error} \ \ \ \ \ \ \ \ \
# \left\{ \begin{array}{l} \text{Variance} \\ \text{Bias}  \end{array} \right. \\ \text{Sloppy}  \end{array} \right.
# \left\{ \begin{array}{l} \text{Explain/Control} \end{array}  \right. \\
# \text{} \\
# \text{Morality}
# \end{array}
# \right.
# \end{array}
# $
#
# $
# \Large
# \begin{array}{ll}
# \textcolor{grey}{\textbf{Social}} \\
# \left\{
# \begin{array}{ll}
# \textcolor{red}{\text{Aristocracy}} \\
# \text{} \\
# \textcolor{#DAA000}{\text{Meritocracy}} \ \
# \left\{ \begin{array}{l} \text{Rigor} \text{} \\ \text{Er\textcolor{grey}{ror}} \ \ \ \ \ \ \ \ \
# \left\{ \begin{array}{l} \text{Variance} \\ \text{\textcolor{grey}{Bias}}  \end{array} \right. \\ \text{\textcolor{grey}{Sloppy}}  \end{array} \right.
# \left\{ \begin{array}{l} \text{Explain/\textcolor{grey}{Control}} \end{array}  \right. \\
# \text{} \\
# \textcolor{green}{\text{Egalitarianism}}
# \end{array}
# \right.
# \end{array}
# $
#
# In this way, you can discuss how each of the different dimensions (Cosmic, Biological, Social) influences or interacts with the components of your primary framework (Truth, Knowledge, Error, etc.).
#
# ---
#
# For a minute I turned truth on its head & elevated morality to the top of the hierarchy to reflect `23` as the year of counterfeiting (I've since restored them to the original hierarchy). the philosophy underlying this has been extensively discussed [elsewhere](https://abikesa.github.io/nabongo/act_1/act_1_0/act_1_0_1/act_1_0_1_2.html). In brief, might makes right and controls the narrative. Then it is the moral campus of the rigorous researcher to uncover these influences (often induces strong correlations in behavior) and present them to the public.
#
# ---
#
# Aristocratic in this sense excludes the "idle rich" but may include those who have inherited wealth but are still [active and disruptive](https://www.youtube.com/watch?v=oR6NBzliM7A) in the economy. Meritocratic is what the middle class may value, and egalitarian is the working class dream of.
